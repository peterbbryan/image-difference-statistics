# %% [markdown]
# # Visual demonstration of transforms

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
from image_difference_statistics.data import camera
from image_difference_statistics.plots import imshow

# %% [markdown]
# ## Original

# %%
imdata = camera()
imshow(imdata=imdata)

# %% [markdown]
# ## Rotations
